# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import accuracy_score
from sklearn import linear_model # for linear regression modeling
from sklearn import preprocessing # for preprocessing like imputting missing values
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
from sklearn import metrics

# %%
# %matplotlib inline

# %%
df0=pd.read_csv('test.csv')
df0.head()
# Out:
#    wind_speed_km/h  wind_dir advance_ratio thrust_coef power_coef    PWR  \
# 0            10.00       180             0       0.144      0.069  0.001
# 1            10.04       210          0.03      0.1416     0.0693  0.001
# 2            10.07       240          0.06       0.139     0.0694  0.001
# 3            10.11       300          0.09       0.136     0.0695  0.001
# 4            10.14        40          0.13      0.1328     0.0694  0.001
#
#   Torque Thrust   RPM        model  prop_diam  max_height_10sec_feet  \
# 0  0.087  0.095  1000  PER3_12x6SF         12                    119
# 1  0.087  0.094  1000  PER3_12x6SF         12                    155
# 2  0.088  0.092  1000  PER3_12x6SF         12                    158
# 3  0.088   0.09  1000  PER3_12x6SF         12                    149
# 4  0.088  0.088  1000  PER3_12x6SF         12                    134
#
#    max_payload_kg efficiency
# 0        7.759800          0
# 1        9.794432     0.0645
# 2        8.717344     0.1262
# 3        6.741127     0.1851
# 4        7.564966     0.2412

# %%
df0.describe()
#df0.shape
# Out:
#        wind_speed_km/h       wind_dir            RPM      prop_diam  \
# count    153632.000000  154038.000000  154038.000000  154038.000000
# mean         14.750444     180.003506   13070.608480       9.302250
# std           4.390270      95.140603    8842.933692       2.854216
# min           5.800000      20.000000    1000.000000       4.000000
# 25%          11.300000     100.000000    6000.000000       7.000000
# 50%          13.440000     180.000000   12000.000000       9.000000
# 75%          17.040000     260.000000   18000.000000      12.000000
# max          41.960000     340.000000   45000.000000      15.000000
#
#        max_height_10sec_feet  max_payload_kg
# count          154038.000000   154038.000000
# mean               82.611778        6.856090
# std                35.809573        1.778289
# min                35.000000        3.000116
# 25%                52.000000        5.546086
# 50%                72.000000        6.748038
# 75%               108.000000        7.987840
# max               189.000000       11.999476

# %%
height = 150
df0.drop(df0[df0['max_height_10sec_feet'] < height].index, inplace = True)
df0.shape
# Out:
# (9702, 14)

# %%
weight = 10
df0.drop(df0[df0['max_payload_kg'] < weight].index, inplace = True)
df0.shape
# Out:
# (8363, 14)

# %%
df1=df0.groupby(by='prop_diam').size()
df1.head(5)
# Out:
# prop_diam
# 12    1470
# 13    3019
# 14    3195
# 15     679
# dtype: int64

# %%
df0.head()
# Out:
#      wind_speed_km/h  wind_dir advance_ratio thrust_coef power_coef    PWR  \
# 10             10.36        50          0.32      0.1059     0.0657  0.001
# 86             12.43       240          0.71      0.0227      0.026  0.014
# 390            10.00       140             0      0.1566     0.0736  4.043
# 607            11.09       320          0.19      0.1019     0.0494  0.124
# 715            16.24       200          0.69      0.0237     0.0203  0.208
#
#      Torque  Thrust    RPM        model  prop_diam  max_height_10sec_feet  \
# 10    0.083    0.07   1000  PER3_12x6SF         12                    150
# 86    0.296   0.135   3000  PER3_12x6SF         12                    151
# 390  18.201  20.271  13999  PER3_12x6SF         12                    158
# 607   1.557   1.683   5000    PER3_12x7         12                    158
# 715   1.635   1.001   8000    PER3_12x7         12                    150
#
#      max_payload_kg efficiency
# 10        10.107539     0.5087
# 86        10.335195     0.6202
# 390       10.097078          0
# 607       10.424136     0.3968
# 715       10.293838     0.8017

# %%
print(df0['model'])
# Out:
# 10            PER3_12x6SF
# 86            PER3_12x6SF
# 390           PER3_12x6SF
# 607             PER3_12x7
# 715             PER3_12x7
#                ...
# 84314    PER3_12x6EP(F2B)
# 84317    PER3_12x6EP(F2B)
# 84320    PER3_12x6EP(F2B)
# 84421    PER3_12x6EP(F2B)
# 84479    PER3_12x6EP(F2B)
# Name: model, Length: 2231, dtype: object

# %%
df=pd.read_csv('combined_prop_UPDATE_diam.csv')

# %%
df.head()
# Out:
#      V     J      Pe      Ct      Cp    PWR Torque Thrust   RPM        model  \
# 0    0     0       0   0.144   0.069  0.001  0.087  0.095  1000  PER3_12x6SF
# 1  0.4  0.03  0.0645  0.1416  0.0693  0.001  0.087  0.094  1000  PER3_12x6SF
# 2  0.7  0.06  0.1262   0.139  0.0694  0.001  0.088  0.092  1000  PER3_12x6SF
# 3  1.1  0.09  0.1851   0.136  0.0695  0.001  0.088   0.09  1000  PER3_12x6SF
# 4  1.4  0.13  0.2412  0.1328  0.0694  0.001  0.088  0.088  1000  PER3_12x6SF
#
#    diameter
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12

# %%
df.V=pd.to_numeric(df.V, errors='coerce')

# %%
df['wind_speed_km/h']=(df.V/10)+10

# %%
df.head(50)
# Out:
#        V     J       Pe       Ct      Cp    PWR Torque Thrust   RPM  \
# 0    0.0     0        0    0.144   0.069  0.001  0.087  0.095  1000
# 1    0.4  0.03   0.0645   0.1416  0.0693  0.001  0.087  0.094  1000
# 2    0.7  0.06   0.1262    0.139  0.0694  0.001  0.088  0.092  1000
# 3    1.1  0.09   0.1851    0.136  0.0695  0.001  0.088   0.09  1000
# 4    1.4  0.13   0.2412   0.1328  0.0694  0.001  0.088  0.088  1000
# 5    1.8  0.16   0.2942   0.1293  0.0693  0.001  0.087  0.085  1000
# 6    2.1  0.19   0.3441   0.1254  0.0689  0.001  0.087  0.083  1000
# 7    2.5  0.22   0.3906   0.1212  0.0685  0.001  0.086   0.08  1000
# 8    2.9  0.25   0.4336   0.1163  0.0677  0.001  0.085  0.077  1000
# 9    3.2  0.28   0.4729   0.1112  0.0667  0.001  0.084  0.073  1000
# 10   3.6  0.32   0.5087   0.1059  0.0657  0.001  0.083   0.07  1000
# 11   3.9  0.35   0.5409   0.1005  0.0644  0.001  0.081  0.066  1000
# 12   4.3  0.38   0.5695    0.095  0.0631  0.001   0.08  0.063  1000
# 13   4.7  0.41   0.5947   0.0894  0.0616  0.001  0.078  0.059  1000
# 14   5.0  0.44   0.6167   0.0836  0.0598  0.001  0.076  0.055  1000
# 15   5.4  0.47   0.6351   0.0776  0.0578  0.001  0.073  0.051  1000
# 16   5.7   0.5   0.6512   0.0714  0.0553  0.001   0.07  0.047  1000
# 17   6.1  0.54   0.6639   0.0649  0.0524  0.001  0.066  0.043  1000
# 18   6.4  0.57   0.6754   0.0602  0.0506  0.001  0.064   0.04  1000
# 19   6.8   0.6   0.6833   0.0554  0.0486  0.001  0.061  0.037  1000
# 20   7.2  0.63   0.6856   0.0497  0.0457  0.001  0.058  0.033  1000
# 21   7.5  0.66   0.6806    0.043  0.0418  0.001  0.053  0.028  1000
# 22   7.9  0.69   0.6662   0.0363  0.0378  0.001  0.048  0.024  1000
# 23   8.2  0.73   0.6431   0.0307  0.0347  0.001  0.044   0.02  1000
# 24   8.6  0.76   0.6194   0.0278   0.034  0.001  0.043  0.018  1000
# 25   9.0  0.79   0.5926   0.0261  0.0347  0.001  0.044  0.017  1000
# 26   9.3  0.82   0.5398    0.022  0.0334  0.001  0.042  0.015  1000
# 27   9.7  0.85   0.4378   0.0152  0.0295  0.001  0.037   0.01  1000
# 28  10.0  0.88   0.2608   0.0073  0.0247      0  0.031  0.005  1000
# 29  10.4  0.91  -0.0307  -0.0007  0.0201      0  0.025      0  1000
# 30   0.0     0        0   0.1463  0.0692  0.011  0.349  0.387  2000
# 31   0.6  0.03   0.0587   0.1444  0.0696  0.011  0.351  0.382  2000
# 32   1.3  0.06   0.1151   0.1423    0.07  0.011  0.353  0.376  2000
# 33   1.9  0.08    0.169     0.14  0.0704  0.011  0.355   0.37  2000
# 34   2.6  0.11   0.2205   0.1374  0.0706  0.011  0.356  0.363  2000
# 35   3.2  0.14   0.2696   0.1347  0.0708  0.011  0.357  0.356  2000
# 36   3.9  0.17   0.3161   0.1317  0.0708  0.011  0.357  0.348  2000
# 37   4.5   0.2     0.36   0.1285  0.0708  0.011  0.357   0.34  2000
# 38   5.1  0.23   0.4012    0.125  0.0706  0.011  0.356   0.33  2000
# 39   5.8  0.25   0.4394   0.1209  0.0701  0.011  0.354   0.32  2000
# 40   6.4  0.28   0.4748   0.1167  0.0696  0.011  0.351  0.308  2000
# 41   7.1  0.31   0.5073   0.1123   0.069  0.011  0.348  0.297  2000
# 42   7.7  0.34   0.5371   0.1078  0.0682  0.011  0.344  0.285  2000
# 43   8.4  0.37   0.5641   0.1032  0.0673  0.011   0.34  0.273  2000
# 44   9.0   0.4   0.5885   0.0983  0.0662  0.011  0.334   0.26  2000
# 45   9.7  0.42   0.6104   0.0932  0.0649   0.01  0.327  0.246  2000
# 46  10.3  0.45   0.6296    0.088  0.0633   0.01   0.32  0.233  2000
# 47  10.9  0.48   0.6462   0.0827  0.0616   0.01  0.311  0.218  2000
# 48  11.6  0.51   0.6601   0.0772  0.0596   0.01  0.301  0.204  2000
# 49  12.2  0.54   0.6716   0.0714  0.0572  0.009  0.289  0.189  2000
#
#           model  diameter  wind_speed_km/h
# 0   PER3_12x6SF        12            10.00
# 1   PER3_12x6SF        12            10.04
# 2   PER3_12x6SF        12            10.07
# 3   PER3_12x6SF        12            10.11
# 4   PER3_12x6SF        12            10.14
# 5   PER3_12x6SF        12            10.18
# 6   PER3_12x6SF        12            10.21
# 7   PER3_12x6SF        12            10.25
# 8   PER3_12x6SF        12            10.29
# 9   PER3_12x6SF        12            10.32
# 10  PER3_12x6SF        12            10.36
# 11  PER3_12x6SF        12            10.39
# 12  PER3_12x6SF        12            10.43
# 13  PER3_12x6SF        12            10.47
# 14  PER3_12x6SF        12            10.50
# 15  PER3_12x6SF        12            10.54
# 16  PER3_12x6SF        12            10.57
# 17  PER3_12x6SF        12            10.61
# 18  PER3_12x6SF        12            10.64
# 19  PER3_12x6SF        12            10.68
# 20  PER3_12x6SF        12            10.72
# 21  PER3_12x6SF        12            10.75
# 22  PER3_12x6SF        12            10.79
# 23  PER3_12x6SF        12            10.82
# 24  PER3_12x6SF        12            10.86
# 25  PER3_12x6SF        12            10.90
# 26  PER3_12x6SF        12            10.93
# 27  PER3_12x6SF        12            10.97
# 28  PER3_12x6SF        12            11.00
# 29  PER3_12x6SF        12            11.04
# 30  PER3_12x6SF        12            10.00
# 31  PER3_12x6SF        12            10.06
# 32  PER3_12x6SF        12            10.13
# 33  PER3_12x6SF        12            10.19
# 34  PER3_12x6SF        12            10.26
# 35  PER3_12x6SF        12            10.32
# 36  PER3_12x6SF        12            10.39
# 37  PER3_12x6SF        12            10.45
# 38  PER3_12x6SF        12            10.51
# 39  PER3_12x6SF        12            10.58
# 40  PER3_12x6SF        12            10.64
# 41  PER3_12x6SF        12            10.71
# 42  PER3_12x6SF        12            10.77
# 43  PER3_12x6SF        12            10.84
# 44  PER3_12x6SF        12            10.90
# 45  PER3_12x6SF        12            10.97
# 46  PER3_12x6SF        12            11.03
# 47  PER3_12x6SF        12            11.09
# 48  PER3_12x6SF        12            11.16
# 49  PER3_12x6SF        12            11.22

# %%
#df['Wind Speed in m/s']=df['Wind Speed']* 0.277778

# %%
df['wind_dir']=np.random.randint(2, 35, size=df.shape[0])*10

# %%
#to create random values for height column
dct = {4: [35, 45], 5: [45, 50], 6: [40, 65], 7: [45, 75], 8: [35, 85], 9: [45, 90], 10: [55, 125], 11: [45, 150], 12: [85, 165], 13: [75, 175], 14: [85, 175], 15: [95, 190]}

def height(diam):
    return np.random.randint(*dct[diam])

df['max_height_10sec_feet'] = df.diameter.map(height)

# %%
#to create random values for weight column
dct1 = {4: [3, 5], 5: [3.5, 5.5], 6: [4, 5.5], 7: [5, 7.5], 8: [5.5, 8], 9: [5.5, 8.5], 10: [5.5, 9.5], 11: [4.5, 10], 12: [5.5, 10.5], 13: [5.5, 11.5], 14: [6.5, 11.5], 15: [5.5, 12]}

def payload(diam):
    return np.random.uniform(*dct1[diam])

df['max_payload_kg'] = df.diameter.map(payload)

# %%
df=df.drop('V',1)

# %%
df
# Out:
#            J      Pe      Ct      Cp    PWR Torque Thrust    RPM        model  \
# 0          0       0   0.144   0.069  0.001  0.087  0.095   1000  PER3_12x6SF
# 1       0.03  0.0645  0.1416  0.0693  0.001  0.087  0.094   1000  PER3_12x6SF
# 2       0.06  0.1262   0.139  0.0694  0.001  0.088  0.092   1000  PER3_12x6SF
# 3       0.09  0.1851   0.136  0.0695  0.001  0.088   0.09   1000  PER3_12x6SF
# 4       0.13  0.2412  0.1328  0.0694  0.001  0.088  0.088   1000  PER3_12x6SF
# ...      ...     ...     ...     ...    ...    ...    ...    ...          ...
# 154033  0.84   0.724  0.0417  0.0481   3.57  9.001  5.446  25000     PER3_9x7
# 154034  0.87  0.6822  0.0328  0.0417  3.096  7.806  4.279  25000     PER3_9x7
# 154035   0.9  0.6028  0.0235  0.0351  2.608  6.575  3.067  25000     PER3_9x7
# 154036  0.94  0.4351  0.0126  0.0271   2.01  5.068  1.646  25000     PER3_9x7
# 154037  0.97  0.0038  0.0001   0.018  1.338  3.373  0.009  25000     PER3_9x7
#
#         diameter  wind_speed_km/h  wind_dir  max_height_10sec_feet  \
# 0             12            10.00       260                    129
# 1             12            10.04       340                    132
# 2             12            10.07       270                     89
# 3             12            10.11       320                    119
# 4             12            10.14       240                    138
# ...          ...              ...       ...                    ...
# 154033         9            27.80        20                     73
# 154034         9            28.51       130                     48
# 154035         9            29.22       210                     77
# 154036         9            29.94       100                     56
# 154037         9            30.65        70                     88
#
#         max_payload_kg
# 0             8.841603
# 1            10.446208
# 2             8.580947
# 3             9.383619
# 4             9.326705
# ...                ...
# 154033        7.891254
# 154034        7.440738
# 154035        8.014874
# 154036        8.152837
# 154037        6.621780
#
# [154038 rows x 14 columns]

# %%
df.rename(columns={'J':'advance_ratio','Ct':'thrust_coef', 'Cp':'power_coef', 'Pe':'efficiency','diameter':'prop_diam'}, inplace=True)

# %%
df
# Out:
#        advance_ratio efficiency thrust_coef power_coef    PWR Torque Thrust  \
# 0                  0          0       0.144      0.069  0.001  0.087  0.095
# 1               0.03     0.0645      0.1416     0.0693  0.001  0.087  0.094
# 2               0.06     0.1262       0.139     0.0694  0.001  0.088  0.092
# 3               0.09     0.1851       0.136     0.0695  0.001  0.088   0.09
# 4               0.13     0.2412      0.1328     0.0694  0.001  0.088  0.088
# ...              ...        ...         ...        ...    ...    ...    ...
# 154033          0.84      0.724      0.0417     0.0481   3.57  9.001  5.446
# 154034          0.87     0.6822      0.0328     0.0417  3.096  7.806  4.279
# 154035           0.9     0.6028      0.0235     0.0351  2.608  6.575  3.067
# 154036          0.94     0.4351      0.0126     0.0271   2.01  5.068  1.646
# 154037          0.97     0.0038      0.0001      0.018  1.338  3.373  0.009
#
#           RPM        model  prop_diam  wind_speed_km/h  wind_dir  \
# 0        1000  PER3_12x6SF         12            10.00       260
# 1        1000  PER3_12x6SF         12            10.04       340
# 2        1000  PER3_12x6SF         12            10.07       270
# 3        1000  PER3_12x6SF         12            10.11       320
# 4        1000  PER3_12x6SF         12            10.14       240
# ...       ...          ...        ...              ...       ...
# 154033  25000     PER3_9x7          9            27.80        20
# 154034  25000     PER3_9x7          9            28.51       130
# 154035  25000     PER3_9x7          9            29.22       210
# 154036  25000     PER3_9x7          9            29.94       100
# 154037  25000     PER3_9x7          9            30.65        70
#
#         max_height_10sec_feet  max_payload_kg
# 0                         129        8.841603
# 1                         132       10.446208
# 2                          89        8.580947
# 3                         119        9.383619
# 4                         138        9.326705
# ...                       ...             ...
# 154033                     73        7.891254
# 154034                     48        7.440738
# 154035                     77        8.014874
# 154036                     56        8.152837
# 154037                     88        6.621780
#
# [154038 rows x 14 columns]

# %%
df=df[['wind_speed_km/h','wind_dir','advance_ratio','thrust_coef','power_coef','PWR',
       'Torque','Thrust','RPM', 'model', 'prop_diam','max_height_10sec_feet','max_payload_kg','efficiency']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154038 entries, 0 to 154037
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   wind_speed_km/h        153632 non-null  float64
#  1   wind_dir               154038 non-null  int32
#  2   advance_ratio          153819 non-null  object
#  3   thrust_coef            153819 non-null  object
#  4   power_coef             153819 non-null  object
#  5   PWR                    153819 non-null  object
#  6   Torque                 153819 non-null  object
#  7   Thrust                 153819 non-null  object
#  8   RPM                    154038 non-null  int64
#  9   model                  154038 non-null  object
#  10  prop_diam              154038 non-null  int64
#  11  max_height_10sec_feet  154038 non-null  int64
#  12  max_payload_kg         154038 non-null  float64
#  13  efficiency             153819 non-null  object
# dtypes: float64(2), int32(1), int64(3), object(8)
# memory usage: 15.9+ MB

# %%
df.advance_ratio=pd.to_numeric(df.advance_ratio,errors='coerce')
df.thrust_coef=pd.to_numeric(df.thrust_coef,errors='coerce')
df.power_coef=pd.to_numeric(df.power_coef,errors='coerce')
df.PWR=pd.to_numeric(df.PWR,errors='coerce')
df.Torque=pd.to_numeric(df.Torque,errors='coerce')
df.Thrust=pd.to_numeric(df.Thrust,errors='coerce')
df.efficiency=pd.to_numeric(df.efficiency,errors='coerce')

# %%
df.efficiency=np.abs(df.efficiency)

# %%
df.describe()
# Out:
#        wind_speed_km/h       wind_dir  advance_ratio    thrust_coef  \
# count    153632.000000  154038.000000  153632.000000  153632.000000
# mean         14.750444     179.496812       0.466509       0.083900
# std           4.390270      95.484600       0.318223       0.050082
# min           5.800000      20.000000      -0.210000      -0.021000
# 25%          11.300000     100.000000       0.210000       0.045600
# 50%          13.440000     180.000000       0.430000       0.085900
# 75%          17.040000     260.000000       0.680000       0.115700
# max          41.960000     340.000000       1.780000       0.321700
#
#           power_coef            PWR         Torque         Thrust  \
# count  153632.000000  153632.000000  153632.000000  153632.000000
# mean        0.068355       1.384535       5.488110       3.841053
# std         0.056842       2.602472       9.898205       5.329687
# min         0.002200       0.000000       0.000000      -2.563000
# 25%         0.031700       0.049000       0.405000       0.364000
# 50%         0.054000       0.321000       1.580000       1.649000
# 75%         0.086600       1.420000       5.700000       5.081000
# max         0.792900      41.903000     146.330000      41.341000
#
#                  RPM      prop_diam  max_height_10sec_feet  max_payload_kg  \
# count  154038.000000  154038.000000          154038.000000   154038.000000
# mean    13070.608480       9.302250              82.602196        6.860015
# std      8842.933692       2.854216              35.847560        1.780205
# min      1000.000000       4.000000              35.000000        3.000046
# 25%      6000.000000       7.000000              52.000000        5.552001
# 50%     12000.000000       9.000000              72.000000        6.759695
# 75%     18000.000000      12.000000             108.000000        8.001695
# max     45000.000000      15.000000             189.000000       11.997984
#
#           efficiency
# count  153632.000000
# mean        0.500839
# std         0.271292
# min         0.000000
# 25%         0.281200
# 50%         0.564000
# 75%         0.728600
# max        11.644100

# %%
#Visualizing the dataframes
pd.DataFrame.hist(df, figsize = [15,15]);

# %%
df.isnull().sum()
# Out:
# wind_speed_km/h          406
# wind_dir                   0
# advance_ratio            406
# thrust_coef              406
# power_coef               406
# PWR                      406
# Torque                   406
# Thrust                   406
# RPM                        0
# model                      0
# prop_diam                  0
# max_height_10sec_feet      0
# max_payload_kg             0
# efficiency               406
# dtype: int64

# %%
def missing_values_table(df):   #source : https://www.analyticsvidhya.com/blog/2020/06/feature-engineering-guide-data-science-hackathons/
       mis_val = df.isnull().sum()
       mis_val_percent = 100 * df.isnull().sum() / len(df)
       mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
       mis_val_table_ren_columns = mis_val_table.rename(
       columns = {0 : 'Missing Values', 1 : '% of Total Values'})
       mis_val_table_ren_columns = mis_val_table_ren_columns[
           mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
       '% of Total Values', ascending=False).round(1)
       print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"     
           "There are " + str(mis_val_table_ren_columns.shape[0]) +
             " columns that have missing values.")
       return mis_val_table_ren_columns
    
missing_values_table(df) #calling the function
# Out:
# Your selected dataframe has 14 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
df=df.dropna()

# %%
df.plot(kind='scatter', x='FIQ_baseline', y='FIQ_24W', figsize=(8,5))

# %%
corr = df.corr()
plt.figure(figsize=(16, 10))
sns.heatmap(corr, xticklabels=corr.columns.values, 
            yticklabels=corr.columns.values,  
            linewidths=.08,                   # set linewidth between entries in matrix
           cbar_kws={"shrink": .7})           # set length of legend on right

# %%
df.columns
# Out:
# Index(['wind_speed_km/h', 'wind_dir', 'advance_ratio', 'thrust_coef',
#        'power_coef', 'PWR', 'Torque', 'Thrust', 'RPM', 'model', 'prop_diam',
#        'max_height_10sec_feet', 'max_payload_kg', 'efficiency'],
#       dtype='object')

# %%
lb_make = LabelEncoder()
df.model=lb_make.fit_transform(df.model)

# %%
X = df.drop(['efficiency'], axis = 1).values # X are the input (or independent) variables
y = df['efficiency'].values # y is output (or dependent) variable

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
# create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Fitting the model
lm = linear_model.LinearRegression()
wind_model = lm.fit(X_train,y_train)

# %%
wind_model.score(X_test, y_test)
# Out:
# 0.4557805868899629

# %%
X = df.drop(['efficiency','model', 'thrust_coef',
       'power_coef', 'PWR','advance_ratio', 'Torque','RPM'], axis = 1).values # X are the input (or independent) variablesmodel = RandomForestRegressor(n_jobs=-1)
y = df['efficiency'].values # y is output (or dependent) variable

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

estimators = np.arange(1, 33, 10)
scores = []
for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))
plt.title("Effect of n_estimators")
plt.xlabel("n_estimator")
plt.ylabel("score")
plt.plot(estimators, scores)

# %%
model.set_params(n_estimators=12)
model.fit(X_train, y_train)
labels=df.drop(['efficiency'],axis=1).columns

# %%
#feature selection
result = pd.DataFrame()
result['feature'] = labels
result['importance'] = model.feature_importances_
result.sort_values(by=['importance'], ascending=False, inplace=True)
result
# Out:
#                   feature  importance
# 2           advance_ratio    0.670245
# 3             thrust_coef    0.234246
# 4              power_coef    0.076127
# 6                  Torque    0.007635
# 0         wind_speed_km/h    0.003155
# 7                  Thrust    0.002618
# 9                   model    0.002083
# 5                     PWR    0.001354
# 10              prop_diam    0.001291
# 8                     RPM    0.000519
# 11  max_height_10sec_feet    0.000279
# 12         max_payload_kg    0.000274
# 1                wind_dir    0.000174

# %%
#X = df.drop(['efficiency'], axis = 1).values # X are the input (or independent) variables

X = df.drop(['efficiency','model', 'thrust_coef',
       'power_coef', 'PWR','advance_ratio', 'Torque','RPM'], axis = 1).values # X are the input (or independent) variablesmodel
y = df['efficiency'].values # y is output (or dependent) variable

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)



#Fitting the model
model = RandomForestRegressor(n_jobs=-1)
model.set_params(n_estimators=15)
wind_model = model.fit(X_train,y_train)


#score the model
wind_model.score(X_test, y_test)
# Out:
# 0.8950754418366058

# %% [markdown]
# I did some analysis and discovered we need adv ratio and thrust/thrust coefficient to get a good score!!!!. If you remove the respective coolumns. the score will be low

# %%
#df.to_csv('test.csv',index=False)

# %%
#Crossvalidating
folds = KFold(n_splits = 5, shuffle = True, random_state = 100)
scores = cross_val_score(model, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.89595063, 0.90014606, 0.90333507, 0.90593524, 0.78859545,
#        0.90302481, 0.87373597, 0.89528135, 0.90102444, 0.87886481])

# %%
y_pred=model.predict(X_test)

# %%
#Computing the RMSE
print('RMSE score: {}'.format(np.sqrt(metrics.mean_squared_error(y_test,y_pred))))
# Out:
# RMSE score: 0.08740297256786599
